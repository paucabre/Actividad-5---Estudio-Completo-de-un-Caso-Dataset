# %% [markdown]
# #### Actividad 5 - Estudio Completo de un Caso/Dataset
# Paula Yurany Cabrera Primiciero

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_edu = pd.read_excel('data_analitica.xlsx')
df_edu.dtypes
# Out:
# id                  int64
# edad                int64
# nivel_edu          object
# ingreso_mensual     int64
# sex                object
# anios_esc           int64
# dtype: object

# %%
df_edu
# Out:
#           id  edad                  nivel_edu  ingreso_mensual     sex  \
# 0          1    56        Secundaria completa             5375   Mujer
# 1          2    52  Medio superior y superior            12900  Hombre
# 2          3    25  Medio superior y superior            12000  Hombre
# 3          4    50        Secundaria completa             3870   Mujer
# 4          5    41  Medio superior y superior             1000   Mujer
# ...      ...   ...                        ...              ...     ...
# 10275  10276    62  Medio superior y superior             7740  Hombre
# 10276  10277    50  Medio superior y superior             9000  Hombre
# 10277  10278    21  Medio superior y superior             6450   Mujer
# 10278  10279    44        Secundaria completa             5590  Hombre
# 10279  10280    33  Medio superior y superior             8000  Hombre
#
#        anios_esc
# 0             12
# 1             17
# 2             15
# 3              9
# 4             17
# ...

# %%
df_edu['nivel_edu'].unique()
# Out:
# array(['Secundaria completa', 'Medio superior y superior',
#        'Primaria incompleta', 'Prrimaria completa'], dtype=object)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='sex', y='ingreso_mensual', data=df_edu)
plt.title('Distribución de Ingresos Mensuales por Género')
plt.xlabel('Género')
plt.ylabel('Ingresos Mensuales')
plt.show()

# %%
plt.figure(figsize=(8,6)) #Se debe crear la figura y especificar el tamaño de esta
sns.scatterplot(x='anios_esc', y='ingreso_mensual', data=df_edu)
plt.title('Correlación entre Años de Escolaridad e Ingreso Mensual')
plt.ylabel('Ingreso Mensual')
plt.xlabel('Años de Escolaridad')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='nivel_edu', y='anios_esc', data=df_edu)
plt.title('Distribución de Años de Escolaridad y Nivel educativo')
plt.ylabel('Años de Escolaridad')
plt.xlabel('Nivel Educativo')
plt.show()

# %%
conteo = df_edu.groupby(['sex', 'nivel_edu']).size().reset_index(name='count')
plt.figure(figsize=(10, 6))
sns.barplot(x='sex', y='count', hue='nivel_edu', data=conteo)
plt.title('Distribución de Personas por Género y Nivel Educativo')
plt.xlabel('Género')
plt.ylabel('Cantidad de Personas')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxenplot(x='nivel_edu', y='anios_esc', data=df_edu)
plt.title('Distribución de Años de Escolaridad y Nivel educativo')
plt.ylabel('Años de Escolaridad')
plt.xlabel('Nivel Educativo')
plt.show()
